# %%
from numpy import *

# %%
# %pylab
# Out:
# Using matplotlib backend: MacOSX
# Populating the interactive namespace from numpy and matplotlib

# %%
a = range(4)

# %%
a = linspace(0, 2*pi, 21)

# %%
# %precision 3
# Out:
# u'%.3f'

# %%
a
# Out:
# array([ 0.   ,  0.314,  0.628,  0.942,  1.257,  1.571,  1.885,  2.199,
#         2.513,  2.827,  3.142,  3.456,  3.77 ,  4.084,  4.398,  4.712,
#         5.027,  5.341,  5.655,  5.969,  6.283])

# %%
# %matplotlib inline

# %%
plot(a, sin(a))

# %%
b = sin(a)

# %%
mask = b > 0

# %%
plot(a[mask], b[mask], 'ro')

# %%
x = np.random.randn(200)
y = np.random.

# %%
color = rand(200)
size = rand(200) * 30

# %%
scatter(x, y, size, color)
colorbar()

# %%
t = np.linspace(0, 2 * pi, 100)
x = sin(t)
y = cos(t)
figure()
plot(x)
figure()
plot(y)

# %%
subplot(1, 2, 1)
plot(x)
subplot(1, 2, 2)
plot(y)

# %%
hist(np.random.randn(10000))
# Out:
# (array([    6.,    97.,   476.,  1474.,  2665.,  2866.,  1711.,   570.,
#           122.,    13.]),
#  array([-3.872, -3.112, -2.352, -1.592, -0.831, -0.071,  0.689,  1.449,
#          2.209,  2.969,  3.729]),
#  <a list of 10 Patch objects>)

# %%
a = np.arange(18).reshape(2, -1)

# %%
a.size
# Out:
# 18

# %%
a.fill(-4.5)

# %%
a
# Out:
# array([[-4, -4, -4, -4, -4, -4, -4, -4, -4],
#        [-4, -4, -4, -4, -4, -4, -4, -4, -4]])
